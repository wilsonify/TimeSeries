# %%
install.packages('TSA')
# Out:
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)

# %%
library(dplyr)
library(TSA)

# %%
for (n in c(10,50,100,1000)){
print(paste("n = ",n))
random   = rnorm(n)
autocov  = acf(random,type = 'covariance')
autocorr =  acf(random,type = 'covariance')
    }
# Out:
# [1] "n =  10"
# [1] "n =  50"
# Plot with title “Series random”
# [1] "n =  100"
# Plot with title “Series random”
# [1] "n =  1000"
# Plot with title “Series random”
# Plot with title “Series random”
