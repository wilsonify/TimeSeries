# %% [markdown]
# 1.2 Consider a signal-plus-noise model of the general form
# $x_t = s_t + w_t$
# , where $w_t$ is Gaussian white noise with $σ^2_w = 1$.
#
# Simulate and plot $n = 200$ observations from each of the following two models (Save the data or your code for use in Problem 1.22 ):
#
# (a) $x_t = s_t + w_t$, for $t = 1,...,200$, where
#
# $$s_t = \begin{cases} 0  , t = 1,...,100 \\
#         10 exp(−\frac{(t−100)}{20} )cos(\frac{2 \pi t}{4})  , t = 101,...,200 \end{cases}$$
#
#
# Hint:
# ```R
# s = c(rep(0,100) , 10*exp(-(1:100)/20)*cos(2*pi*1:100/4))
# x = ts(s + rnorm(200, 0, 1))
# plot(x)
# ```
#
# (b)
# $x_t = s_t + w_t$, for $t = 1,...,200$,
#
# where
# $$
# s_t = \begin{cases} 0, t = 1,...,100 \\
#       10exp(−\frac{(t−100)}{200} ) cos(\frac{2 \pi t}{4}), t = 101,...,200.
#       \end{cases}
# $$
#
# ```R
# s = c(rep(0,100) , 10*exp(-(1:100)/200)*cos(2*pi*1:100/4))
# x = ts(s + rnorm(200, 0, 1))
# plot(x)
# ```
#
# (c) Compare the general appearance of the series (a) and (b) with the earthquake series and the explosion series shown in Figure 1.7.
#
# In addition, plot (or sketch) and compare the signal modulators
#
# (a) $exp(\frac{-t}{20})$ and (b) $exp(\frac{-t}{200})$
#
# , for t = 1,2,...,100.

# %% [markdown]
# 1.5 For the two series, $x_t$, in Problem 1.2 (a) and (b):

# %% [markdown]
# (a) Compute and plot the mean functions $\mu_x(t)$, for $t = 1,...,200$.

# %%
s = c(rep(0,100) , 10*exp(-(1:100)/20)*cos(2*pi*1:100/4)) 
x = ts(s + rnorm(200, 0, 1)) 
mean(x)
# Out:
# [1] -0.001137347

# %%
s = c(rep(0,100) , 10*exp(-(1:100)/200)*cos(2*pi*1:100/4)) 
x = ts(s + rnorm(200, 0, 1)) 
mean(x)
# Out:
# [1] 0.07413533

# %% [markdown]
# (b)Calculate the autocovariance functions, $\gamma_x(s,t)$, for $s,t = 1,...,200$.

# %%
s = c(rep(0,100) , 10*exp(-(1:100)/200)*cos(2*pi*1:100/4)) 
x = ts(s + rnorm(200, 0, 1)) 
acf(x,type = 'covariance')
# Out:
# Plot with title “Series  x”

# %%
s = c(rep(0,100) , 10*exp(-(1:100)/20)*cos(2*pi*1:100/4)) 
x = ts(s + rnorm(200, 0, 1)) 
acf(x,type = 'covariance')
# Out:
# Plot with title “Series  x”
